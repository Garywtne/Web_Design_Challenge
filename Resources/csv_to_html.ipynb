# %%
#import dependencies
import pandas as pd

# %%
#import cities.csv csv to dataframe
df = pd.read_csv("cities.csv")
df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 0          0          pevek  69.7008  170.3133      4.05        87
# 1          1  san cristobal   7.7669  -72.2250     68.11        74
# 2          2        macamic  48.7502  -78.9996     32.88        88
# 3          3      ilulissat  69.2167  -51.1000     21.22        93
# 4          4  mar del plata -38.0023  -57.5575     51.10        87
# ..       ...            ...      ...       ...       ...       ...
# 558      558         palana  59.1167  159.9667     19.13        94
# 559      559         mattru   7.6244  -11.8332     74.32        94
# 560      560    broken hill -31.9500  141.4333     76.71        19
# 561      561        donetsk  48.0000   37.8000     38.07        92
# 562      562      roebourne -20.7833  117.1333     92.28        28
#
#      Cloudiness  Wind Speed Country        Date
# 0           100        1.03      RU  1649831944
# 1           100        2.37      VE  1649831944
# ...

# %%
#export dataframe to html
print(df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>pevek</td>
#       <td>69.7008</td>
#       <td>170.3133</td>
#       <td>4.05</td>
#       <td>87</td>
#       <td>100</td>
#       <td>1.03</td>
#       <td>RU</td>
#       <td>1649831944</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>san cristobal</td>
#       <td>7.7669</td>
#       <td>-72.2250</td>
#       <td>68.11</td>
#       <td>74</td>
#       <td>100</td>
#       <td>2.37</td>
#       <td>VE</td>
#       <td>1649831944</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>macamic</td>
#       <td>48.7502</td>
#       <td>-78.9996</td>
# ...
